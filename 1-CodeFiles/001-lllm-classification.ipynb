# %% [markdown]
# #### Classification
# 1. Local  Ollama  Performnance issue
# 2. Openrouter   make account and copy the starter script make it up and running
# 3. Paid ones   Azure OpenAI , Google Gemini

# %%
from langchain_huggingface import ChatHuggingFace ,HuggingFaceEndpoint

llm_endpoint = HuggingFaceEndpoint(repo_id="meta-llama/Meta-Llama-3-8B-Instruct"
                                   ,temperature=0.7
                                   ,max_new_tokens=512
                                   ,task="text-generation")

llm_endpoint
# Out:
# Running cells with 'autogen_env (3.12.0) (Python 3.12.0)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: 'd:/Project/Autogen/autogen_env/Scripts/python.exe -m pip install ipykernel -U --force-reinstall'

# %%
llm = ChatHuggingFace(llm=llm_endpoint)
llm
query="what is machine learning"
response = llm.invoke(query)

print(response.content[:200])
# Out:
# Running cells with 'autogen_env (3.12.0) (Python 3.12.0)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: 'd:/Project/Autogen/autogen_env/Scripts/python.exe -m pip install ipykernel -U --force-reinstall'
